# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\Titanic-Dataset.csv") #importing the csv format file to be dataframed

# %%
df #printing the dataframe
df.count() #counting total
df.head() #printing top units (default=5)
df.tail() #printing last units (default=5)
df.describe() #shows count, max, std etc
df.info() #info about the dataframe
df['Fare'].value_counts() #counting values in a particular column
(df['Fare'].value_counts()).sort_values #counting values of a column in a sorted way
(df['SibSp'].value_counts()).sort_values(ascending=False) #changing the order of the sorted values which by default is ascending
df.sort_values('Fare') #sorting for 1 value
df.sort_values(['Fare','Embarked']) #sorting for more than 1 value
df.drop_duplicates(subset=['Ticket']) #deleting duplicates in a particular column
df.drop_duplicates(subset=['Ticket','Name']).shape #telling the number of rows and columns after removing duplicates
categories=df.groupby('Sex') #grouping
categories #printing grouped data
len(df) #length of the dataframe
len(categories) #length of the sorted dataframe
categories.size() #telling the total no. of data in the sorted data
categories.first() #telling the first value in the sorted data
df.rename(columns={'Sex':'Gender'}) #renaming column
pd.concat([df,cc]) #for joining 2 different dataframes
df.join(cc) #combining different dataframes which have an index in common
df.isnull() #tells is the cell null or not using true and false
df.isnull().sum() #tells the number of nulls in each column
