# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
tip=pd.read_csv(r"C:\Users\Hianshi\Downloads\Tip.csv")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tip['total_bill'].value_counts()
# Out:
# total_bill
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: count, Length: 229, dtype: int64

# %%
(tip['smoker'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of smoker
# No     151
# Yes     93
# Name: count, dtype: int64>

# %%
(tip['smoker'].value_counts()).sort_values(ascending=False)
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tip.sort_values(['time'])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 154       19.77  2.00    Male     No   Sun  Dinner     4
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# ..          ...   ...     ...    ...   ...     ...   ...
# 127       14.52  2.00  Female     No  Thur   Lunch     2
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 129       22.82  2.18    Male     No  Thur   Lunch     3
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
#
# [244 rows x 7 columns]

# %%
tip.sort_values(['tip','time'])
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
tip.drop_duplicates(subset=['total_bill'])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [229 rows x 7 columns]

# %%
tip.drop_duplicates(subset=['total_bill','tip']).shape
# Out:
# (242, 7)

# %%
categories=tip.groupby('size') 
categories

# %%
len(tip)
# Out:
# 244

# %%
len(categories)
# Out:
# 6

# %%
categories.size()
# Out:
# size
# 1      4
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# dtype: int64

# %%
categories.first()
# Out:
#       total_bill   tip     sex smoker   day    time
# size
# 1           3.07  1.00  Female    Yes   Sat  Dinner
# 2          16.99  1.01  Female     No   Sun  Dinner
# 3          10.34  1.66    Male     No   Sun  Dinner
# 4          24.59  3.61  Female     No   Sun  Dinner
# 5          41.19  5.00    Male     No  Thur   Lunch
# 6          29.80  4.20  Female     No  Thur   Lunch

# %%
tip.rename(columns={'total_bill':'bill'})
# Out:
#       bill   tip     sex smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #SEABORN

# %%
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tip,x='total_bill',y='tip',kind='scatter')

# %%
male = tip.query("sex == 'male'")
sns.lineplot(data=tip, x="size", y="tip")
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.displot(data=tip, x="size")

# %%
sns.displot(data=tip, x="size",kind='kde')

# %%
sns.displot(data=tip, x="size", kde=True)

# %%
sns.histplot(data=tip, x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tip, y="tip")
# Out:
# <Axes: xlabel='Count', ylabel='tip'>

# %%
sns.histplot(data=tip, x="tip", bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(data=tip, x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data=tip, y="tip")
# Out:
# <Axes: xlabel='Density', ylabel='tip'>

# %%
sns.kdeplot(data=tip)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=tip, x="total_bill", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(x=tip["size"])
# Out:
# <Axes: xlabel='size'>

# %%
sns.boxplot(data=tip, x="time", y="tip", hue="sex")
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.violinplot(x=tip["smoker"])
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.violinplot(data=tip, x="sex", y="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='smoker'>

# %%
sns.violinplot(data=tip, x="time", y="smoker", hue="sex")
# Out:
# <Axes: xlabel='time', ylabel='smoker'>

# %%
sns.barplot(tip, x="sex", y="tip")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(tip, x="sex", y="total_bill", hue="time", legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(tip, x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(tip, x="time", hue="size")
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(tip, x="day", hue="size", stat="percent")
# Out:
# <Axes: xlabel='day', ylabel='percent'>

# %%
tip.drop_duplicates(subset=['tip'])
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 233       10.77  1.47    Male     No  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [123 rows x 7 columns]

# %%
tip= sns.load_dataset("Tips").pivot_table(index="time", columns="day", values="total_bill")
sns.heatmap(tip)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(tip, annot=True)
# Out:
# <Axes: xlabel='day', ylabel='time'>

# %%
tip=sns.load_dataset('tips')
sns.pairplot(data=tip)

# %%
tip=sns.load_dataset('tips')
sns.pairplot(tip , hue='time')
