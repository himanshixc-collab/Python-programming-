# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# #CSV

# %%
titanic=pd.read_csv(r"C:\Users\Hianshi\Downloads\Titanic-Dataset.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic['Fare'].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
(titanic['SibSp'].value_counts()).sort_values
# Out:
# <bound method Series.sort_values of SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64>

# %%
(titanic['SibSp'].value_counts()).sort_values(ascending=False)
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
titanic.sort_values(['Fare'])
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
titanic.sort_values(['Fare','Embarked'])
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 179          180         0       3                 Leonard, Mr. Lionel
# 263          264         0       1               Harrison, Mr. William
# 271          272         1       3        Tornquist, Mr. William Henry
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# ..           ...       ...     ...                                 ...
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 438          439         0       1                   Fortune, Mr. Mark
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
titanic.drop_duplicates(subset=['Ticket'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.drop_duplicates(subset=['Ticket','Name']).shape
# Out:
# (891, 12)

# %%
categories=titanic.groupby('Sex') 
categories

# %%
len(titanic)
# Out:
# 891

# %%
len(categories)
# Out:
# 2

# %%
categories.size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
categories.first()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female            2         1       1
# male              1         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# male                              Braund, Mr. Owen Harris  22.0      1      0
#
#            Ticket     Fare Cabin Embarked
# Sex
# female   PC 17599  71.2833   C85        C
# male    A/5 21171   7.2500   E46        S

# %%
titanic.rename(columns={'Sex':'Gender'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #SEABORN

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.relplot(data=titanic,x='fare',y='age',kind='scatter')

# %%
male = titanic.query("sex == 'male'")
sns.lineplot(data=titanic, x="age", y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.displot(data=titanic, x="age")

# %%
sns.displot(data=titanic, x="age",kind='kde')

# %%
sns.displot(data=titanic, x="age", kde=True)

# %%
sns.histplot(data=titanic, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic, y="age")
# Out:
# <Axes: xlabel='Count', ylabel='age'>

# %%
sns.histplot(data=titanic, x="age", bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(data=titanic, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=titanic, y="age")
# Out:
# <Axes: xlabel='Density', ylabel='age'>

# %%
sns.kdeplot(data=titanic)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=titanic, x="fare", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(x=titanic["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=titanic, x="class", y="age", hue="sex")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x=titanic["survived"])
# Out:
# <Axes: xlabel='survived'>

# %%
sns.violinplot(data=titanic, x="sex", y="class")
# Out:
# <Axes: xlabel='sex', ylabel='class'>

# %%
sns.violinplot(data=titanic, x="who", y="class", hue="sex")
# Out:
# <Axes: xlabel='who', ylabel='class'>

# %%
sns.barplot(titanic, x="sex", y="fare")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(titanic, x="who", y="fare", hue="class", legend=False)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.countplot(titanic, x="class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(titanic, x="class", hue="who")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(titanic, x="class", hue="survived", stat="percent")
# Out:
# <Axes: xlabel='class', ylabel='percent'>

# %%
titanic.drop_duplicates(subset=['age'])
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.00      1      0   7.2500        S   Third
# 1           1       1  female  38.00      1      0  71.2833        C   First
# 2           1       3  female  26.00      0      0   7.9250        S   Third
# 3           1       1  female  35.00      1      0  53.1000        S   First
# 5           0       3    male    NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 767         0       3  female  30.50      0      0   7.7500        Q   Third
# 803         1       3    male   0.42      0      1   8.5167        C   Third
# 843         0       3    male  34.50      0      0   6.4375        C   Third
# 851         0       3    male  74.00      0      0   7.7750        S   Third
#
# ...

# %%
titanic= sns.load_dataset("titanic")
df=titanic.pivot_table(index="pclass", columns="sex", values="survived")
sns.heatmap(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df, annot=True)
# Out:
# <Axes: xlabel='sex', ylabel='pclass'>

# %%
sns.pairplot(titanic)

# %%
sns.pairplot(titanic, hue='who')
