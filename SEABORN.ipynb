# %%
import seaborn as sns   
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Superstore_data.csv') #telling the data
df
# Out:
#       Row ID         Category Sub-Category     Sales  Quantity  Discount  \
# 0          1        Furniture    Bookcases  261.9600         2      0.00
# 1          2        Furniture       Chairs  731.9400         3      0.00
# 2          3  Office Supplies       Labels   14.6200         2      0.00
# 3          4        Furniture       Tables  957.5775         5      0.45
# 4          5  Office Supplies      Storage   22.3680         2      0.20
# ...      ...              ...          ...       ...       ...       ...
# 9989    9990        Furniture  Furnishings   25.2480         3      0.20
# 9990    9991        Furniture  Furnishings   91.9600         2      0.00
# 9991    9992       Technology       Phones  258.5760         2      0.20
# 9992    9993  Office Supplies        Paper   29.6000         4      0.00
# 9993    9994  Office Supplies   Appliances  243.1600         2      0.00
#
#         Profit
# 0      41.9136
# 1     219.5820
# 2       6.8714
# 3    -383.0310
# ...

# %%
df2=pd.read_csv(r"C:\Users\HP\Downloads\Titanic-Dataset.csv") 
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3=pd.read_csv(r"C:\Users\HP\Downloads\HousePrice_Data")
df3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df3=pd.read_csv(r"C:\Users\HP\Downloads\HousePrice_Data")
#       2 df3
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
sns.scatterplot(data=df,x='Quantity',y='Sales')
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
sns.relplot(data=df,x='Quantity',y='Sales',kind='scatter')

# %%
info=df.query("Category=='Furniture'")
sns.lineplot(data=info,x="Discount",y="Profit")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
dfinf=df.pivot_table(index="Quantity",columns="Category",values="Profit")
dfinf.head()
# Out:
# Category  Furniture  Office Supplies  Technology
# Quantity
# 1         -0.547125         6.900834   22.723831
# 2          4.632534        13.607266   37.073123
# 3          5.482997        21.045700   52.774370
# 4          7.911537        16.480730  132.114634
# 5         12.491970        27.191741  115.146384

# %%
sns.lineplot(data=df2["SibSp"])
# Out:
# <Axes: ylabel='SibSp'>

# %%
sns.lineplot(data=df2)
# Out:
# <Axes: >
