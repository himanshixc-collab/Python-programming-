# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints= np.array([0,8])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,9])
ypoints=np.array([3,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,9,7,9,3])
ypoints=np.array([3,10,0,200,75])

plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker='o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker='s')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker='.')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dotted')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
yplot=np.array([3,8,1,10])

plt.plot(ypoints,color='r')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linewidth='20.5')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y1=np.array([5,6,22,9])
y2=np.array([6,3,7,1])

plt.plot(y1)
plt.plot(y2)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([43,53,67,73,75,83,87,96,103,187])
y=np.array([664,333,775,545,472,855,725,756,371,931])

plt.plot(x,y)

plt.xlabel("average pulse")
plt.ylabel("calorie burnage")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.title("sports watch data")
plt.xlabel("average pulse")
plt.ylabel("calorie burnage")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot 1
x=np.array([0,1,2,3])
y=np.array([5,67,3,2])

plt.subplot(1,2,1)
plt.plot(x,y)

#plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([5,7,5,2,6,3,4,7,4,11,2,5,4])
y=np.array([33,55,67,42,78,89,67,56,98,45,38,75,37])

plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])

plt.bar(x,y)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])

plt.bar(x,y, color="red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])

plt.bar(x,y,width=0.01)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.random.normal(170,10,258)
plt.hist(x)
plt.show()
